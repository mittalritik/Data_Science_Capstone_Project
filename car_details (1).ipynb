# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Load the dataset
df = pd.read_csv("CAR DETAILS.csv")
df.shape
# Out:
# (4340, 8)

# %%
#To get the column names 
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
# to know more more information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
# Check for null values
print(df.isnull().sum())
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#we use (value_counts) to know to know the sold numbers of each car use (plot) to draw the graph
plt.figure(figsize=(10, 3)) 
df["name"].value_counts(normalize = True)[:5].plot(kind = 'bar') 
plt.show()

# %%
# We will display sales by count in pie graphs
labels = df["name"][:20].value_counts().index #We chose only twenty
sizes = df["name"][:20].value_counts() # We chose only twenty
data = df.groupby(['name'])['name'].count().sort_values(ascending=False)#to extract the count
x = data.index #to extract the brand name
y = data.values#to extract the count to brand 
colors = ['#F8EEFB','#66b3ff','#8000FF','#ffcc99',"#00FF1B","#FF8040","#F8AEF8"]#color choice
plt.figure(figsize = (8,8))#Determine the size of the graph
# Creating explode data
#explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=10)#Fomat pie
#plt.title('Name',color = 'black',fontsize = 15)#Fomat title
#plt.legend()#
#plt.legend(title = "Cars")#title legend
#plt.legend(wedges, cars, title ="Cars",loc ="center left",bbox_to_anchor =(1, 0, 0.5, 1))
#myexplode = [0.2, 0, 0, 0]
plt.show()#view

# %%
#To know countnvalue in year coulmn
df.year.value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %%
#Here I am using another way to display the graph by seaborn we imported it in the beginning
sns.countplot(data=df,x="year",palette="icefire")
plt.xticks(rotation=90)
plt.xlabel("YEAR",fontsize=10,color="RED")
plt.ylabel("COUNT",fontsize=10,color="RED")
plt.title("YEAR COUNT",color="RED")
plt.show()

# %%
#We will display bar graphs
df["fuel"].value_counts(sort =True).plot(kind="bar", color=["blue"], figsize=(8, 4) , title='Fuel');

# %%
#We will display bar graphs
df["seller_type"].value_counts(sort = True).plot(kind="bar", color=["blue"], figsize=(8, 4) , title='Seller type');

# %%
#We will display bar graphs
df["transmission"].value_counts(sort = True).plot(kind="bar", color=["blue"], figsize=(8, 4) , title='Transmission');

# %% [markdown]
# Conclusion:
# Best selling brand is Maruti then Hyundai.
# Manuals sell more than automatics.
# The newer the car the better it sells.
# Individuals sell more.
# Petrol and Diesel sell more.
# Most sales were made in 2017.
